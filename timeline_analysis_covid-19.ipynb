# %% [markdown]
# # Auther:- Mohammad Aamir Rangrez

# %% [markdown]
# # GRIP - The Spark Foundation- Data Science & Business Analytics Internship

# %% [markdown]
# # Task 7

# %% [markdown]
# - Create a storyboard showing spread of Covid-19 cases in your country or any
# region (Asia, Europe, BRICS etc)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Markdown, display
from datetime import datetime as d
from ipywidgets import interact,interactive,fixed,interact_manual
import ipywidgets as widgets
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
import cufflinks
from plotly.subplots import make_subplots
import dateutil
import plotly.express as px
import plotly.io as pio
import datetime
from statistics import mean 
import datetime as dt
import requests
from itertools import chain
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import folium
from folium import plugins
import os
import sys
from scipy.optimize import curve_fit
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import r2_score
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # COVID19 SPREAD WORLDWIDE

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## Reading the Dataset

# %%
covid_data = pd.read_csv (r'covid_data_csv.csv')

# %%
print(covid_data)
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 92786      ZWE    Africa     Zimbabwe  2021-05-28      38918.0       64.0
# 92787      ZWE    Africa     Zimbabwe  2021-05-29      38933.0       15.0
# 92788      ZWE    Africa     Zimbabwe  2021-05-30      38944.0       11.0
# 92789      ZWE    Africa     Zimbabwe  2021-05-31      38961.0       17.0
# 92790      ZWE    Africa     Zimbabwe  2021-06-01      38998.0       37.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 92786              36.286        1592.0         0.0                0.857  ...
# 92787              36.286        1594.0         2.0                1.143  ...
# 92788              37.429        1594.0         0.0                1.143  ...
# 92789              37.857        1594.0         0.0                1.143  ...
# 92790              41.714        1599.0         5.0                1.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 92786        1899.775             21.4                307.846
# 92787        1899.775             21.4                307.846
# 92788        1899.775             21.4                307.846
# 92789        1899.775             21.4                307.846
# 92790        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 92786                 1.82             1.6          30.7
# 92787                 1.82             1.6          30.7
# 92788                 1.82             1.6          30.7
# 92789                 1.82             1.6          30.7
# 92790                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 92786                  36.791                         1.7            61.49
# 92787                  36.791                         1.7            61.49
# 92788                  36.791                         1.7            61.49
# 92789                  36.791                         1.7            61.49
# 92790                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 92786                    0.571
# 92787                    0.571
# 92788                    0.571
# 92789                    0.571
# 92790                    0.571
#
# [92791 rows x 59 columns]

# %% [markdown]
# ## Information of the Dataset

# %%
print(covid_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92791 entries, 0 to 92790
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               92791 non-null  object
#  1   continent                              88392 non-null  object
#  2   location                               92791 non-null  object
#  3   date                                   92791 non-null  object
#  4   total_cases                            89951 non-null  float64
#  5   new_cases                              89950 non-null  float64
#  6   new_cases_smoothed                     88938 non-null  float64
#  7   total_deaths                           80028 non-null  float64
#  8   new_deaths                             80186 non-null  float64
#  9   new_deaths_smoothed                    88938 non-null  float64
#  10  total_cases_per_million                89470 non-null  float64
#  11  new_cases_per_million                  89469 non-null  float64
#  12  new_cases_smoothed_per_million         88462 non-null  float64
#  13  total_deaths_per_million               79560 non-null  float64
#  14  new_deaths_per_million                 79718 non-null  float64
#  15  new_deaths_smoothed_per_million        88462 non-null  float64
#  16  reproduction_rate                      74655 non-null  float64
#  17  icu_patients                           9331 non-null   float64
#  18  icu_patients_per_million               9331 non-null   float64
#  19  hosp_patients                          11598 non-null  float64
#  20  hosp_patients_per_million              11598 non-null  float64
#  21  weekly_icu_admissions                  811 non-null    float64
#  22  weekly_icu_admissions_per_million      811 non-null    float64
#  23  weekly_hosp_admissions                 1466 non-null   float64
#  24  weekly_hosp_admissions_per_million     1466 non-null   float64
#  25  new_tests                              41916 non-null  float64
#  26  total_tests                            41610 non-null  float64
#  27  total_tests_per_thousand               41610 non-null  float64
#  28  new_tests_per_thousand                 41916 non-null  float64
#  29  new_tests_smoothed                     48576 non-null  float64
#  30  new_tests_smoothed_per_thousand        48576 non-null  float64
#  31  positive_rate                          45759 non-null  float64
#  32  tests_per_case                         45163 non-null  float64
#  33  tests_units                            50153 non-null  object
#  34  total_vaccinations                     12933 non-null  float64
#  35  people_vaccinated                      12137 non-null  float64
#  36  people_fully_vaccinated                9489 non-null   float64
#  37  new_vaccinations                       10836 non-null  float64
#  38  new_vaccinations_smoothed              22074 non-null  float64
#  39  total_vaccinations_per_hundred         12933 non-null  float64
#  40  people_vaccinated_per_hundred          12137 non-null  float64
#  41  people_fully_vaccinated_per_hundred    9489 non-null   float64
#  42  new_vaccinations_smoothed_per_million  22074 non-null  float64
#  43  stringency_index                       78686 non-null  float64
#  44  population                             92176 non-null  float64
#  45  population_density                     86292 non-null  float64
#  46  median_age                             83273 non-null  float64
#  47  aged_65_older                          82333 non-null  float64
#  48  aged_70_older                          82811 non-null  float64
#  49  gdp_per_capita                         83500 non-null  float64
#  50  extreme_poverty                        56478 non-null  float64
#  51  cardiovasc_death_rate                  83681 non-null  float64
#  52  diabetes_prevalence                    85604 non-null  float64
#  53  female_smokers                         65503 non-null  float64
#  54  male_smokers                           64542 non-null  float64
#  55  handwashing_facilities                 42048 non-null  float64
#  56  hospital_beds_per_thousand             76291 non-null  float64
#  57  life_expectancy                        88112 non-null  float64
#  58  human_development_index                83860 non-null  float64
# dtypes: float64(54), object(5)
# memory usage: 41.8+ MB
# None

# %%
covid_data.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  8.995100e+04  8.995000e+04        88938.000000  8.002800e+04
# mean   9.468349e+05  6.063400e+03         6080.376189  2.544549e+04
# std    6.533073e+06  3.859747e+04        37879.000942  1.517258e+05
# min    1.000000e+00 -3.486670e+05        -6223.000000  1.000000e+00
# 25%    1.094000e+03  2.000000e+00            7.143000  4.900000e+01
# 50%    1.206200e+04  7.100000e+01           88.857000  3.410000e+02
# 75%    1.276445e+05  7.880000e+02          828.571000  3.325000e+03
# max    1.710582e+08  1.498213e+06       826374.286000  3.561896e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  80186.000000         88938.000000             89470.000000
# mean     142.319545           127.265312             11621.884609
# std      781.930528           722.035348             21862.808441
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               228.590000
# 50%        2.000000             1.286000              1561.156000
# 75%       18.000000            14.143000             11638.734250
# max    17906.000000         14436.286000            177687.180000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           89469.000000                    88462.000000
# mean               76.093384                       76.326154
# std               201.018343                      158.258986
# min             -5160.525000                     -276.825000
# 25%                 0.207000                        1.234000
# 50%                 7.992000                       10.570000
# 75%                70.613000                       79.286000
# max             18293.675000                     4083.500000
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count              79560.000000  ...    83500.000000     56478.000000
# mean                 253.018458  ...    19292.420100        13.383540
# std                  441.270712  ...    19962.688936        19.955253
# min                    0.001000  ...      661.240000         0.100000
# 25%                    7.510750  ...     4466.507000         0.600000
# 50%                   45.903000  ...    12951.839000         2.200000
# 75%                  278.783000  ...    27216.445000        21.200000
# max                 3080.737000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count           83681.000000         85604.000000    65503.000000
# mean              258.157224             7.884512       10.540707
# std               118.900699             4.074640       10.429524
# min                79.370000             0.990000        0.100000
# 25%               167.295000             5.310000        1.900000
# 50%               242.648000             7.110000        6.300000
# 75%               329.635000            10.080000       19.300000
# max               724.417000            30.530000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  64542.000000            42048.000000                76291.000000
# mean      32.674370               50.870727                    3.028586
# std       13.477791               31.761174                    2.460887
# min        7.700000                1.188000                    0.100000
# 25%       21.600000               20.859000                    1.300000
# 50%       31.400000               49.839000                    2.400000
# 75%       41.100000               83.241000                    3.861000
# max       78.100000              100.000000                   13.800000
#
#        life_expectancy  human_development_index
# count     88112.000000             83860.000000
# mean         73.232977                 0.727689
# std           7.562312                 0.150397
# min          53.280000                 0.394000
# 25%          67.920000                 0.602000
# 50%          74.620000                 0.748000
# 75%          78.740000                 0.848000
# max          86.750000                 0.957000
#
# [8 rows x 54 columns]

# %% [markdown]
# ## Checking for count of all the unique values present for each attribute

# %%
covid_data.nunique()
# Out:
# iso_code                                   230
# continent                                    6
# location                                   230
# date                                       518
# total_cases                              49196
# new_cases                                12302
# new_cases_smoothed                       23653
# total_deaths                             18745
# new_deaths                                2891
# new_deaths_smoothed                       6519
# total_cases_per_million                  69780
# new_cases_per_million                    39467
# new_cases_smoothed_per_million           44567
# total_deaths_per_million                 43477
# new_deaths_per_million                    7413
# new_deaths_smoothed_per_million           8799
# reproduction_rate                          366
# icu_patients                              2497
# icu_patients_per_million                  5303
# hosp_patients                             4886
# hosp_patients_per_million                 8799
# weekly_icu_admissions                      621
# weekly_icu_admissions_per_million          616
# weekly_hosp_admissions                    1304
# weekly_hosp_admissions_per_million        1300
# new_tests                                22600
# total_tests                              40635
# total_tests_per_thousand                 35961
# new_tests_per_thousand                    7358
# new_tests_smoothed                       25551
# new_tests_smoothed_per_thousand           7643
# positive_rate                              561
# tests_per_case                            5286
# tests_units                                  4
# total_vaccinations                       12450
# people_vaccinated                        11564
# people_fully_vaccinated                   8904
# new_vaccinations                          9579
# new_vaccinations_smoothed                13340
# total_vaccinations_per_hundred            4669
# people_vaccinated_per_hundred             3760
# people_fully_vaccinated_per_hundred       2338
# new_vaccinations_smoothed_per_million     7274
# stringency_index                           176
# population                                 228
# population_density                         207
# median_age                                 136
# aged_65_older                              188
# aged_70_older                              186
# gdp_per_capita                             194
# extreme_poverty                             76
# cardiovasc_death_rate                      190
# diabetes_prevalence                        146
# female_smokers                             111
# male_smokers                               126
# handwashing_facilities                      96
# hospital_beds_per_thousand                 101
# life_expectancy                            205
# human_development_index                    153
# dtype: int64

# %% [markdown]
# ## Checking for count of NULL values for each column:

# %%
covid_data.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 4399
# location                                     0
# date                                         0
# total_cases                               2840
# new_cases                                 2841
# new_cases_smoothed                        3853
# total_deaths                             12763
# new_deaths                               12605
# new_deaths_smoothed                       3853
# total_cases_per_million                   3321
# new_cases_per_million                     3322
# new_cases_smoothed_per_million            4329
# total_deaths_per_million                 13231
# new_deaths_per_million                   13073
# new_deaths_smoothed_per_million           4329
# reproduction_rate                        18136
# icu_patients                             83460
# icu_patients_per_million                 83460
# hosp_patients                            81193
# hosp_patients_per_million                81193
# weekly_icu_admissions                    91980
# weekly_icu_admissions_per_million        91980
# weekly_hosp_admissions                   91325
# weekly_hosp_admissions_per_million       91325
# new_tests                                50875
# total_tests                              51181
# total_tests_per_thousand                 51181
# new_tests_per_thousand                   50875
# new_tests_smoothed                       44215
# new_tests_smoothed_per_thousand          44215
# positive_rate                            47032
# tests_per_case                           47628
# tests_units                              42638
# total_vaccinations                       79858
# people_vaccinated                        80654
# people_fully_vaccinated                  83302
# new_vaccinations                         81955
# new_vaccinations_smoothed                70717
# total_vaccinations_per_hundred           79858
# people_vaccinated_per_hundred            80654
# people_fully_vaccinated_per_hundred      83302
# new_vaccinations_smoothed_per_million    70717
# stringency_index                         14105
# population                                 615
# population_density                        6499
# median_age                                9518
# aged_65_older                            10458
# aged_70_older                             9980
# gdp_per_capita                            9291
# extreme_poverty                          36313
# cardiovasc_death_rate                     9110
# diabetes_prevalence                       7187
# female_smokers                           27288
# male_smokers                             28249
# handwashing_facilities                   50743
# hospital_beds_per_thousand               16500
# life_expectancy                           4679
# human_development_index                   8931
# dtype: int64

# %%
covid_data.continent.value_counts()[0:10]
# Out:
# Africa           24009
# Asia             22129
# Europe           22038
# North America    11348
# South America     5619
# Oceania           3249
# Name: continent, dtype: int64

# %%
covid_data['date'] = pd.to_datetime(covid_data['date'])
raw_df_latest_date = covid_data['date'].to_list()[-1].strftime('%b %d, %Y')

# %% [markdown]
# Top 8 Countries with Most Cases

# %%
#BARGRAPH OF TOP 8 COUNTRIES WITH MAXIMUM NEW CASES
max_cases=covid_data.sort_values("location", ascending=False)
max_cases = max_cases[max_cases['date']==raw_df_latest_date]
max_cases = max_cases[~max_cases['location'].isin(['World','International'])]

plt.figure(figsize=(10,5))
sns.lineplot(x='location', y='total_cases', data=max_cases[0:8], color='red')
#sns.barplot(x='location', y='total_cases', data=covid_data[0:5])
plt.xticks(x='location', rotation=30)
plt.yticks(y='total_cases')
plt.title("BARGRAPH OF TOP 8 COUNTRIES (total cases))")
# Out:
# Text(0.5, 1.0, 'BARGRAPH OF TOP 8 COUNTRIES (total cases))')

# %% [markdown]
# ## Collecting Asia Data from the given dataset

# %%
asia_data = covid_data[covid_data['continent'] == 'Asia']
asia_data = asia_data[asia_data['date']==raw_df_latest_date]
asia_data = asia_data[~asia_data['location'].isin(['World','International'])]
asia_data
# Out:
#       iso_code continent              location       date  total_cases  \
# 463        AFG      Asia           Afghanistan 2021-06-01      72977.0
# 4296       ARM      Asia               Armenia 2021-06-01     222778.0
# 6271       AZE      Asia            Azerbaijan 2021-06-01     334132.0
# 7178       BHR      Asia               Bahrain 2021-06-01     242790.0
# 7634       BGD      Asia            Bangladesh 2021-06-01     802305.0
# 10487      BTN      Asia                Bhutan 2021-06-01       1632.0
# 12739      BRN      Asia                Brunei 2021-06-01        244.0
# 14559      KHM      Asia              Cambodia 2021-06-01      30710.0
# 17944      CHN      Asia                 China 2021-06-01      91197.0
# 32040      GEO      Asia               Georgia 2021-06-01     345196.0
# 37447      HKG      Asia             Hong Kong 2021-06-01      11848.0
# 38853      IND      Asia                 India 2021-06-01   28175044.0
# 39310      IDN      Asia             Indonesia 2021-06-01    1826527.0
# 40260      IRN      Asia                  Iran 2021-06-01    2923823.0
# 40724      IRQ      Asia                  Iraq 2021-06-01    1205522.0
# 41785      ISR      Asia                Israel 2021-06-01     839511.0
# 43218      JPN      Asia                 Japan 2021-06-01     749829.0
# 43745      JOR      Asia                Jordan 2021-06-01     737284.0
# 44191      KAZ      Asia            Kazakhstan 2021-06-01     444377.0
# 45568      KWT      Asia                Kuwait 2021-06-01     310501.0
# 46009      KGZ      Asia            Kyrgyzstan 2021-06-01     105111.0
# 46444      LAO      Asia                  Laos 2021-06-01       1929.0
# 47374      LBN      Asia               Lebanon 2021-06-01     540630.0
# 51511      MYS      Asia              Malaysia 2021-06-01     579462.0
# 51962      MDV      Asia              Maldives 2021-06-01      65164.0
# 55990      MNG      Asia              Mongolia 2021-06-01      60372.0
# 57892      MMR      Asia               Myanmar 2021-06-01     143751.0
# 58872      NPL      Asia                 Nepal 2021-06-01     566587.0
# 63759      OMN      Asia                  Oman 2021-06-01     218271.0
# 64222      PAK      Asia              Pakistan 2021-06-01     924667.0
# 89333      160.0             235.143         690.0         0.0
# 90931      193.0             242.000          48.0         1.0
# 91910        9.0              11.571        1322.0         1.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 463                 19.571  ...        1803.987              NaN
# 4296                 6.429  ...        8787.580              1.8
# 6271                 6.286  ...       15847.419              NaN
# 7178                20.429  ...       43290.705              NaN
# 7634                31.286  ...        3523.984             14.8
# 10487                0.000  ...        8708.597              1.5
# 12739                0.000  ...       71809.251              NaN
# 14559                5.286  ...        3645.070              NaN
# 17944                0.000  ...       15308.712              0.7
# 32040               21.429  ...        9745.079              4.2
# 37447                0.000  ...       56054.920              NaN
# 38853             2929.571  ...        6426.674             21.2
# 39310              156.571  ...       11188.744              5.7
# 40260              181.571  ...       19082.620              0.2
# 40724               23.429  ...       15663.986              2.5
# 41785                1.000  ...       33132.320              0.5
# 43218               92.857  ...       39002.223              NaN
# 43745               12.571  ...        8337.490              0.1
# 44191                3.286  ...       24055.588              0.1
# 45568                4.143  ...       65530.537              NaN
# 46009                7.143  ...        3393.474              1.4
# 46444                0.143  ...        6397.360             22.7
# 47374                6.429  ...       13367.565              NaN
# 51511               71.143  ...       26808.164              0.1
# 51962                3.571  ...       15183.616              NaN
# 55990                4.143  ...       11840.846              0.5
# 57892                0.143  ...        5591.597              6.4
# 58872              107.714  ...        2442.804             15.0
# 63759               10.286  ...       37960.709              NaN
# 64222               66.429  ...        5034.708              4.0
# 64676                3.286  ...        4449.898              1.0
# 67019              141.857  ...        7599.188              NaN
# 68397                1.571  ...      116935.600              NaN
# 72744               14.143  ...       49045.411              NaN
# 75035                0.143  ...       85535.383              NaN
# 78117                3.571  ...       35938.374              0.2
# 79519               30.714  ...       11669.077              0.7
# 81798                4.143  ...             NaN              NaN
# 82301               14.571  ...             NaN              NaN
# 82699                0.000  ...        2896.913              4.8
# 83657               33.857  ...       16277.671              0.1
# 84094                0.429  ...        6570.102             30.3
# 85933              147.857  ...       25129.341              0.2
# 87458                3.714  ...       67293.483              NaN
# 89333                1.143  ...        6253.104              NaN
# 90931                0.571  ...        6171.884              2.0
# 91910                1.571  ...        1479.147             18.8
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 463                  597.029                 9.59             NaN
# 4296                 341.010                 7.11             1.5
# 6271                 559.812                 7.11             0.3
# 7178                 151.689                16.52             5.8
# 7634                 298.003                 8.38             1.0
# 10487                217.066                 9.75             NaN
# 12739                201.285                12.79             2.0
# 14559                270.892                 4.00             2.0
# 17944                261.899                 9.74             1.9
# 32040                496.218                 7.11             5.3
# 37447                    NaN                 8.33             NaN
# 38853                282.280                10.39             1.9
# 39310                342.864                 6.32             2.8
# 40260                270.308                 9.59             0.8
# 40724                218.612                 8.83             NaN
# 41785                 93.320                 6.74            15.4
# 43218                 79.370                 5.72            11.2
# 43745                208.257                11.75             NaN
# 44191                466.792                 7.11             7.0
# 45568                132.235                15.84             2.7
# 46009                436.362                 7.11             3.6
# 46444                368.111                 4.00             7.3
# 47374                266.591                12.71            26.9
# 75035       18.0              25.571          33.0         0.0
# 84094      167.0             192.143          16.0         0.0
# 12739        2.0               1.143           3.0         0.0
# 46444       17.0               7.286           3.0         0.0
# 10487       12.0              29.857           1.0         0.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 38853             2929.571  ...        6426.674             21.2
# 40260              181.571  ...       19082.620              0.2
# 39310              156.571  ...       11188.744              5.7
# 85933              147.857  ...       25129.341              0.2
# 67019              141.857  ...        7599.188              NaN
# 64222               66.429  ...        5034.708              4.0
# 40724               23.429  ...       15663.986              2.5
# 43218               92.857  ...       39002.223              NaN
# 7634                31.286  ...        3523.984             14.8
# 43745               12.571  ...        8337.490              0.1
# 47374                6.429  ...       13367.565              NaN
# 58872              107.714  ...        2442.804             15.0
# 72744               14.143  ...       49045.411              NaN
# 41785                1.000  ...       33132.320              0.5
# 6271                 6.286  ...       15847.419              NaN
# 32040               21.429  ...        9745.079              4.2
# 17944                0.000  ...       15308.712              0.7
# 4296                 6.429  ...        8787.580              1.8
# 64676                3.286  ...        4449.898              1.0
# 44191                3.286  ...       24055.588              0.1
# 57892                0.143  ...        5591.597              6.4
# 463                 19.571  ...        1803.987              NaN
# 51511               71.143  ...       26808.164              0.1
# 63759               10.286  ...       37960.709              NaN
# 78117                3.571  ...       35938.374              0.2
# 46009                7.143  ...        3393.474              1.4
# 45568                4.143  ...       65530.537              NaN
# 81798                4.143  ...             NaN              NaN
# 87458                3.714  ...       67293.483              NaN
# 79519               30.714  ...       11669.077              0.7
# 91910                1.571  ...        1479.147             18.8
# 83657               33.857  ...       16277.671              0.1
# 7178                20.429  ...       43290.705              NaN
# 89333                1.143  ...        6253.104              NaN
# 68397                1.571  ...      116935.600              NaN
# 55990                4.143  ...       11840.846              0.5
# 14559                5.286  ...        3645.070              NaN
# 37447                0.000  ...       56054.920              NaN
# 51962                3.571  ...       15183.616              NaN
# 82301               14.571  ...             NaN              NaN
# 82699                0.000  ...        2896.913              4.8
# 90931                0.571  ...        6171.884              2.0
# 75035                0.143  ...       85535.383              NaN
# 84094                0.429  ...        6570.102             30.3
# 12739                0.000  ...       71809.251              NaN
# 46444                0.143  ...        6397.360             22.7
# 10487                0.000  ...        8708.597              1.5
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 38853                282.280                10.39             1.9
# 40260                270.308                 9.59             0.8
# 39310                342.864                 6.32             2.8
# 85933                171.285                12.13            14.1
# 67019                370.437                 7.07             7.8
# 64222                423.031                 8.35             2.8
# 40724                218.612                 8.83             NaN
# 43218                 79.370                 5.72            11.2
# 7634                 298.003                 8.38             1.0
# 43745                208.257                11.75             NaN
# 47374                266.591                12.71            26.9
# 58872                260.797                 7.26             9.5
# 72744                259.538                17.72             1.8
# 41785                 93.320                 6.74            15.4
# 6271                 559.812                 7.11             0.3
# 32040                496.218                 7.11             5.3
# 17944                261.899                 9.74             1.9
# 4296                 341.010                 7.11             1.5
# 64676                265.910                10.59             NaN
# 44191                466.792                 7.11             7.0
# 57892                202.104                 4.61             6.3
# 90931      193.0             242.000          48.0         1.0
# 75035       18.0              25.571          33.0         0.0
# 84094      167.0             192.143          16.0         0.0
# 12739        2.0               1.143           3.0         0.0
# 46444       17.0               7.286           3.0         0.0
# 10487       12.0              29.857           1.0         0.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 38853             2929.571  ...        6426.674             21.2
# 40260              181.571  ...       19082.620              0.2
# 39310              156.571  ...       11188.744              5.7
# 85933              147.857  ...       25129.341              0.2
# 67019              141.857  ...        7599.188              NaN
# 64222               66.429  ...        5034.708              4.0
# 40724               23.429  ...       15663.986              2.5
# 43218               92.857  ...       39002.223              NaN
# 7634                31.286  ...        3523.984             14.8
# 43745               12.571  ...        8337.490              0.1
# 47374                6.429  ...       13367.565              NaN
# 58872              107.714  ...        2442.804             15.0
# 72744               14.143  ...       49045.411              NaN
# 41785                1.000  ...       33132.320              0.5
# 6271                 6.286  ...       15847.419              NaN
# 32040               21.429  ...        9745.079              4.2
# 17944                0.000  ...       15308.712              0.7
# 4296                 6.429  ...        8787.580              1.8
# 64676                3.286  ...        4449.898              1.0
# 44191                3.286  ...       24055.588              0.1
# 57892                0.143  ...        5591.597              6.4
# 463                 19.571  ...        1803.987              NaN
# 51511               71.143  ...       26808.164              0.1
# 63759               10.286  ...       37960.709              NaN
# 78117                3.571  ...       35938.374              0.2
# 46009                7.143  ...        3393.474              1.4
# 45568                4.143  ...       65530.537              NaN
# 81798                4.143  ...             NaN              NaN
# 87458                3.714  ...       67293.483              NaN
# 79519               30.714  ...       11669.077              0.7
# 91910                1.571  ...        1479.147             18.8
# 83657               33.857  ...       16277.671              0.1
# 7178                20.429  ...       43290.705              NaN
# 89333                1.143  ...        6253.104              NaN
# 68397                1.571  ...      116935.600              NaN
# 55990                4.143  ...       11840.846              0.5
# 14559                5.286  ...        3645.070              NaN
# 37447                0.000  ...       56054.920              NaN
# 51962                3.571  ...       15183.616              NaN
# 82301               14.571  ...             NaN              NaN
# 82699                0.000  ...        2896.913              4.8
# 90931                0.571  ...        6171.884              2.0
# 75035                0.143  ...       85535.383              NaN
# 84094                0.429  ...        6570.102             30.3
# 12739                0.000  ...       71809.251              NaN
# 46444                0.143  ...        6397.360             22.7
# 10487                0.000  ...        8708.597              1.5
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 38853                282.280                10.39             1.9
# 40260                270.308                 9.59             0.8
# 39310                342.864                 6.32             2.8
# 85933                171.285                12.13            14.1
# 67019                370.437                 7.07             7.8
# 64222                423.031                 8.35             2.8
# 40724                218.612                 8.83             NaN
# 43218                 79.370                 5.72            11.2
# 7634                 298.003                 8.38             1.0
# 43745                208.257                11.75             NaN
# 47374                266.591                12.71            26.9
# 58872                260.797                 7.26             9.5
# 72744                259.538                17.72             1.8
# 41785                 93.320                 6.74            15.4
# 6271                 559.812                 7.11             0.3
# 32040                496.218                 7.11             5.3
# 17944                261.899                 9.74             1.9
# 4296                 341.010                 7.11             1.5
# 64676                265.910                10.59             NaN
# 44191                466.792                 7.11             7.0
# 7634             72.59                    0.632
# 43745            74.53                    0.729
# 47374            78.93                    0.744
# 58872            70.78                    0.602
# 72744            75.13                    0.854
# 41785            82.97                    0.919
# 6271             73.00                    0.756
# 32040            73.77                    0.812
# 17944            76.91                    0.761
# 4296             75.09                    0.776
# 64676            74.05                    0.708
# 44191            73.60                    0.825
# 57892            67.13                    0.583
# 463              64.83                    0.511
# 51511            76.16                    0.810
# 63759            77.86                    0.813
# 78117            83.03                    0.916
# 46009            71.45                    0.697
# 45568            75.49                    0.806
# 81798            72.70                    0.567
# 87458            77.97                    0.890
# 79519            76.98                    0.782
# 91910            66.12                    0.470
# 83657            77.15                    0.777
# 7178             77.29                    0.852
# 89333            71.72                    0.720
# 68397            80.23                    0.848
# 55990            69.87                    0.737
# 14559            69.82                    0.594
# 37447            84.86                    0.949
# 51962            78.92                    0.740
# 82301            80.46                      NaN
# 82699            71.10                    0.668
# 90931            75.40                    0.704
# 75035            83.62                    0.938
# 84094            69.50                    0.606
# 12739            75.86                    0.838
# 46444            67.92                    0.613
# 10487            71.78                    0.654
#
# [47 rows x 59 columns]

# %%
plt.figure(figsize=(10,5))
#sns.lineplot(x='location', y='total_deaths', data=top_10_deaths[0:10], color='red')
sns.barplot(x='location', y='total_deaths', data=most_asia_death[0:5])
plt.xticks(x='location', rotation=30)
plt.yticks(y='total_deaths')
plt.title("Total deaths across asian countries")
# Out:
# Text(0.5, 1.0, 'Total deaths across asian countries')

# %% [markdown]
# # Least Asia Cases

# %%
least_asia_cases = asia_data.sort_values("total_cases_per_million",ascending =True)
least_asia_cases.head()
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 17944      CHN      Asia    China 2021-06-01      91197.0       24.0
# 90931      VNM      Asia  Vietnam 2021-06-01       7625.0      193.0
# 91910      YEM      Asia    Yemen 2021-06-01       6751.0        9.0
# 46444      LAO      Asia     Laos 2021-06-01       1929.0       17.0
# 82301      TWN      Asia   Taiwan 2021-06-01       8842.0      331.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 17944              18.143        4636.0         0.0                0.000  ...
# 90931             242.000          48.0         1.0                0.571  ...
# 91910              11.571        1322.0         1.0                1.571  ...
# 46444               7.286           3.0         0.0                0.143  ...
# 82301             483.714         137.0        13.0               14.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 17944       15308.712              0.7                261.899
# 90931        6171.884              2.0                245.465
# 91910        1479.147             18.8                495.003
# 46444        6397.360             22.7                368.111
# 82301             NaN              NaN                103.957
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 17944                 9.74             1.9          48.4
# 90931                 6.00             1.0          45.9
# 91910                 5.35             7.6          29.2
# 46444                 4.00             7.3          51.2
# 82301                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 17944                     NaN                        4.34            76.91
# 90931                  85.847                        2.60            75.40
# 91910                  49.542                        0.70            66.12
# 46444                  49.839                        1.50            67.92
# 82301                     NaN                         NaN            80.46
#
#        human_development_index
# 17944                    0.761
# 90931                    0.704
# 91910                    0.470
# 46444                    0.613
# 82301                      NaN
#
# [5 rows x 59 columns]

# %%
plt.figure(figsize=(10,5))
#sns.lineplot(x='location', y='total_deaths', data=top_10_deaths[0:10], color='red')
sns.barplot(x='location', y='total_deaths', data=least_asia_cases[0:5])
plt.xticks(x='location', rotation=30)
plt.yticks(y='total_deaths')
plt.title("Total deaths across Asia (Top 10 countries)")
# Out:
# Text(0.5, 1.0, 'Total deaths across Asia (Top 10 countries)')

# %% [markdown]
# # Total Cases v/s Total Deaths

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='total_cases',y='total_deaths',data=asia_data,color="red")
plt.title("Total Cases vs Total Death Scenarios")
# Out:
# Text(0.5, 1.0, 'Total Cases vs Total Death Scenarios')

# %%
df_asia=asia_data[["date","total_cases","new_cases","total_deaths","new_tests","total_tests",
                  "location",'new_deaths_per_million','total_tests_per_thousand','new_tests_per_thousand',
                  'positive_rate','new_deaths']]
df_asia.head()
# Out:
#            date  total_cases  new_cases  total_deaths  new_tests  total_tests  \
# 463  2021-06-01      72977.0     1139.0        2973.0        NaN          NaN
# 4296 2021-06-01     222778.0      108.0        4445.0        NaN          NaN
# 6271 2021-06-01     334132.0      176.0        4921.0     4815.0    3513989.0
# 7178 2021-06-01     242790.0     2259.0        1009.0    17285.0    4643466.0
# 7634 2021-06-01     802305.0     1765.0       12660.0        NaN          NaN
#
#          location  new_deaths_per_million  total_tests_per_thousand  \
# 463   Afghanistan                   0.745                       NaN
# 4296      Armenia                   2.362                       NaN
# 6271   Azerbaijan                   0.789                   346.575
# 7178      Bahrain                  17.043                  2728.909
# 7634   Bangladesh                   0.249                       NaN
#
#       new_tests_per_thousand  positive_rate  new_deaths
# 463                      NaN            NaN        29.0
# 4296                     NaN            NaN         7.0
# 6271                   0.475            NaN         8.0
# 7178                  10.158            NaN        29.0
# 7634                     NaN            NaN        41.0

# %%
fig=plt.figure(figsize=(15,10))

sns.heatmap(df_asia.corr(),cmap="Blues",annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x='total_tests',y='positive_rate',data=covid_data,color="blue")
plt.title("Total Tests vs Positive Rate",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total Tests vs Positive Rate')

# %%
vaccination_data=covid_data[covid_data["date"]=="2021-03-21"]
vaccination_data=vaccination_data[~vaccination_data["location"].isin(["World","International"])]
max_vaccinated=vaccination_data.sort_values("total_vaccinations",ascending= False)
max_vaccinated.head()
# Out:
#        iso_code      continent        location       date  total_cases  \
# 4785   OWID_ASI            NaN            Asia 2021-03-21   26981166.0
# 61670  OWID_NAM            NaN   North America 2021-03-21   34363806.0
# 88371       USA  North America   United States 2021-03-21   29821754.0
# 28347  OWID_EUR            NaN          Europe 2021-03-21   37786630.0
# 28843  OWID_EUN            NaN  European Union 2021-03-21   25142828.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 4785    125343.0          114063.429      416502.0       889.0
# 61670    42237.0           66485.429      791158.0       718.0
# 88371    33768.0           54438.286      543004.0       440.0
# 28347   161266.0          188432.143      879694.0      2039.0
# 28843   126906.0          147242.571      591181.0      1353.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 4785               909.143  ...             NaN              NaN
# 61670             1597.571  ...             NaN              NaN
# 88371             1024.286  ...       54225.446              1.2
# 28347             3101.714  ...             NaN              NaN
# 28843             2166.857  ...             NaN              NaN
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 4785                     NaN                  NaN             NaN
# 61670                    NaN                  NaN             NaN
# 88371                151.089                10.79            19.1
# 28347                    NaN                  NaN             NaN
# 28843                    NaN                  NaN             NaN
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 4785            NaN                     NaN                         NaN
# 61670           NaN                     NaN                         NaN
# 88371          24.6                     NaN                        2.77
# 28347           NaN                     NaN                         NaN
# 28843           NaN                     NaN                         NaN
#
#        life_expectancy  human_development_index
# 4785               NaN                      NaN
# 61670              NaN                      NaN
# 88371            78.86                    0.926
# 28347              NaN                      NaN
# 28843              NaN                      NaN
#
# [5 rows x 59 columns]

# %%
least_vaccinated=vaccination_data.sort_values("total_vaccinations",ascending= True)
least_vaccinated.head()
# Out:
#       iso_code      continent       location       date  total_cases  \
# 82229      TWN           Asia         Taiwan 2021-03-21       1006.0
# 6642       BHS  North America        Bahamas 2021-03-21       8800.0
# 49040      LIE         Europe  Liechtenstein 2021-03-21       2628.0
# 85413      TUN         Africa        Tunisia 2021-03-21     245706.0
# 55010      MDA         Europe        Moldova 2021-03-21     215034.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 82229        1.0               3.000          10.0         0.0
# 6642         0.0              20.286         186.0         0.0
# 49040        1.0               2.286          56.0         0.0
# 85413      301.0             553.143        8546.0        20.0
# 55010      831.0            1510.143        4559.0        28.0
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 82229                0.000  ...             NaN              NaN
# 6642                 0.143  ...       27717.847              NaN
# 49040                0.143  ...             NaN              NaN
# 85413               22.429  ...       10849.297              2.0
# 55010               32.714  ...        5189.972              0.2
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 82229                103.957                  NaN             NaN
# 6642                 235.954                13.17             3.1
# 49040                    NaN                 7.77             NaN
# 85413                318.991                 8.52             1.1
# 55010                408.502                 5.72             5.9
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 82229           NaN                     NaN                         NaN
# 6642           20.4                     NaN                       2.900
# 49040           NaN                     NaN                       2.397
# 85413          65.8                  78.687                       2.300
# 55010          44.6                  86.979                       5.800
#
#        life_expectancy  human_development_index
# 82229            80.46                      NaN
# 6642             73.92                    0.814
# 49040            82.49                    0.919
# 85413            76.70                    0.740
# 55010            71.90                    0.750
#
# [5 rows x 59 columns]

# %%
fig=plt.figure(figsize=(25,10))
plt.subplot(1,2,1)
plt.barh(max_vaccinated["location"][:10],max_vaccinated["total_vaccinations"][:10],color="#0E6655")
plt.title("Top 10 Countries with Maximum Number of Vaccinated People",fontsize=20)
plt.xlabel("Vaccinations",fontsize=15)
plt.ylabel("Countries",fontsize=15)
plt.subplot(1,2,2)
plt.barh(least_vaccinated["location"][:10],least_vaccinated["total_vaccinations"][:10],color="#2471A3")
plt.title("10 Countries with Least Number of Vaccinated People", fontsize=20)
plt.xlabel("Vaccinations",fontsize=15)
plt.ylabel("Countries",fontsize=15)

plt.show()

# %% [markdown]
# From graph 1, we can infer that United States is having the Maximum number of Vaccinated population followed by other nine countries. And From graph 2, it is observed that Belize is having least number of vaccinated population followed by other countries.
